# %%
from bs4 import BeautifulSoup
import requests
import shutil
import matplotlib.pyplot as plt
import matplotlib.image as mpim

# %%
html_page = requests.get('https://books.toscrape.com/')
soup = BeautifulSoup(html_page.content, 'html.parser')
warning = soup.find('div', class_="")
book_container = warning.nextSibling.nextSibling
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-8e38f24c6d0a> in <module>
#       2 soup = BeautifulSoup(html_page.content, 'html.parser')
#       3 warning = soup.find('div', class_="lot-details-page bg-gray")
# ----> 4 book_container = warning.nextSibling.nextSibling
#
# AttributeError: 'NoneType' object has no attribute 'nextSibling'

# %%
images = book_container.findAll('img')
example = images[0]
example
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1f66146e3392> in <module>
# ----> 1 images = book_container.findAll('img')
#       2 example = images[0]
#       3 example
#
# NameError: name 'book_container' is not defined

# %%
example.attrs['src']
# Out:
# 'media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg'

# %%
url_base = "http://books.toscrape.com/" #Original website
url_ext = example.attrs['src'] #The extension you pulled earlier
full_url = url_base + url_ext #Combining first 2 variables to create       a complete URL
r = requests.get(full_url, stream=True) #Get request on full_url
if r.status_code == 200:                     #200 status code = OK
   with open("images/book1.jpg", 'wb') as f: 
      r.raw.decode_content = True
      shutil.copyfileobj(r.raw, f)

# %%
img = mpim.imread('images/book1.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
import pandas as pd
from IPython.display import Image, HTML

# %%
row_1 = [example.attrs['alt'], '<img src="images/book1.jpg"/>']
df = pd.DataFrame(row_1).transpose()
df.columns = ['Title', 'Cover']
HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Title</th>
#       <th>Cover</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A Light in the Attic</td>
#       <td><img src="images/book1.jpg"/></td>
#     </tr>
#   </tbody>
# </table>

# %%
from bs4 import BeautifulSoup
soup = make_soup('https://www.copart.com/lot/26755730/Photos/salvage-2008-audi-a4-2-0t-quattro-nj-trenton')
for img in soup.findAll('img'):
    print(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-aaaef80a554f> in <module>
#       1 from bs4 import BeautifulSoup
# ----> 2 soup = make_soup('https://www.copart.com/lot/26755730/Photos/salvage-2008-audi-a4-2-0t-quattro-nj-trenton')
#       3 for img in soup.findAll('img'):
#       4     print(img)
#
# NameError: name 'make_soup' is not defined
